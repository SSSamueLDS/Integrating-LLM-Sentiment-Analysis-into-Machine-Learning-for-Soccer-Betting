# %% [markdown]
# <h1>Scraping BBC Webpages</h1>

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import json
import os

#web scrape the most relevant link from the search results
def scrape_bbc_article(url_to_scrape):

    driver = webdriver.Chrome()
    #set timeout to 10 seconds
    driver.implicitly_wait(10)
    driver.get(url_to_scrape)

    #find by id='main-content
    main_tag = driver.find_element(By.ID, 'main-content')

    #Find all h1 tags
    #find all div tag with data-component="subheadline-block" or data-component="text-block"
    blocks =main_tag.find_elements(By.TAG_NAME, 'h1')
    blocks = blocks + main_tag.find_elements(By.CSS_SELECTOR, 'div[data-component="subheadline-block"], div[data-component="text-block"]')

    #check that the title contains a digit at least
    #if not, return None
    if 'live' not in url_to_scrape:
        title = blocks[0].text if blocks else None
        if title and not any(char.isdigit() for char in title): #might need to override this at times
            print(f"Title does not contain a digit: {title}")
            driver.quit()
            return None
    #get the text from the blocks and concatenate them in a string, with new line between each block
    text_blocks = [block.text for block in blocks]
    commentary_text = "\n".join(text_blocks)

    #Close the browser
    driver.quit()

    return commentary_text

input_file = "../dataset/epl_sentiment_analysis/bbc_links/bbc_links_2023.json"
output_file = "../dataset/epl_sentiment_analysis/bbc_articles/bbc_articles_2023.json"

# Load the JSON file
with open(input_file, "r") as file:
    links = json.load(file)

#Load output file if it exists, if not none
existing_data = None
if os.path.exists(output_file):
    with open(output_file, "r") as file:
        existing_data = json.load(file)
        print(f"Loaded existing data from {output_file}")

# Initialize an empty list to store the articles
output = []

count = 0
# Iterate through the links and scrape the articles
for link in links:

    
    # Check if the link already exists in the existing data. Use id to check
    if existing_data:
        if any(item['id'] == link['id'] and item.get('article_text') is not None for item in existing_data):
            #add the existing data to the output
            for item in existing_data:
                if item['id'] == link['id']:
                    output.append(item)
            continue
    count += 1
    print(f"Scraping article {count}: {link['bbc_link']}")

    try:
        bbc_link = link.get('bbc_link')
        if bbc_link:
            article_text = scrape_bbc_article(bbc_link)
            output.append({
                'id': link['id'],
                'date': link['date'],
                'home_team': link['home_team'],
                'away_team': link['away_team'],
                'bbc_link': bbc_link,
                'article_text': article_text
            })
        else:
            output.append({'id': link['id'],
                'date': link['date'],
                'home_team': link['home_team'],
                'away_team': link['away_team'],
                'bbc_link': bbc_link,
                'article_text': None})

    except Exception as e:
        print(f"Error scraping {link['bbc_link']}: {e}")
        output.append({
            'id': link['id'],
            'date': link['date'],
            'home_team': link['home_team'],
            'away_team': link['away_team'],
            'bbc_link': link['bbc_link'],
            'article_text': None
        })
        
#output the articles to a json file
with open(output_file, "w") as file:
    json.dump(output, file, indent=4)
print(f"Output saved to {output_file}")
# Out:
# Scraping article 1: https://www.bbc.com/sport/football/66402155
# Scraping article 2: https://www.bbc.com/sport/football/66413654
# Scraping article 3: https://www.bbc.com/sport/football/66413643
# Scraping article 4: https://www.bbc.com/sport/football/66413647
# Scraping article 5: https://www.bbc.com/sport/football/66413648
# Scraping article 6: https://www.bbc.com/sport/football/66413645
# Scraping article 7: https://www.bbc.com/sport/football/66413644
# Scraping article 8: https://www.bbc.com/sport/football/66419908
# Scraping article 9: https://www.bbc.com/sport/football/66419907
# Scraping article 10: https://www.bbc.com/sport/football/66424895
# Scraping article 11: https://www.bbc.com/sport/football/66470075
# Scraping article 12: https://www.bbc.com/sport/football/66482708
# Scraping article 13: https://www.bbc.com/sport/football/66482707
# Scraping article 14: https://www.bbc.com/sport/football/66482704
# Scraping article 15: https://www.bbc.com/sport/football/66482710
# Scraping article 16: https://www.bbc.com/sport/football/66482703
# Scraping article 17: https://www.bbc.com/sport/football/66490164
# Scraping article 18: https://www.bbc.com/sport/football/66490161
# Scraping article 19: https://www.bbc.com/sport/football/66495070
# Scraping article 20: https://www.bbc.com/sport/football/66540847
# Scraping article 21: https://www.bbc.com/sport/football/66552610
# Scraping article 22: https://www.bbc.com/sport/football/66629637
# Scraping article 23: https://www.bbc.com/sport/football/66552613
# Scraping article 24: https://www.bbc.com/sport/football/66552609
# Scraping article 25: https://www.bbc.com/sport/football/66552611
# Scraping article 26: https://www.bbc.com/sport/football/66552607
# Scraping article 27: https://www.bbc.com/sport/football/66561748
# Scraping article 28: https://www.bbc.com/sport/football/66561746
# Scraping article 29: https://www.bbc.com/sport/football/66561747
# Scraping article 30: https://www.bbc.com/sport/football/66612700
# Scraping article 31: https://www.bbc.com/sport/football/66625190
# Scraping article 32: https://www.bbc.com/sport/football/66625192
# Scraping article 33: https://www.bbc.co.uk/sport/football/66625193
# Scraping article 34: https://www.bbc.com/sport/football/66625186
# Scraping article 35: https://www.bbc.com/sport/football/66625183
# Scraping article 36: https://www.bbc.com/sport/football/66625184
# Scraping article 37: https://www.bbc.com/sport/football/66631581
# Scraping article 38: https://www.bbc.com/sport/football/66631568
# Scraping article 39: https://www.bbc.com/sport/football/66631567
# Scraping article 40: https://www.bbc.com/sport/football/66760560
# Scraping article 41: https://www.bbc.com/sport/football/66760559
# Scraping article 42: https://www.bbc.com/sport/football/66760557
# Scraping article 43: https://www.bbc.com/sport/football/66760556
# Scraping article 44: https://www.bbc.com/sport/football/66760558
# Scraping article 45: https://www.bbc.com/sport/football/66760554
# Scraping article 46: https://www.bbc.com/sport/football/66760555
# Scraping article 47: https://www.bbc.com/sport/football/66766249
# Scraping article 48: https://www.bbc.com/sport/football/66766251
# Scraping article 49: https://www.bbc.com/sport/football/66771266
# Scraping article 50: https://www.bbc.com/sport/football/66828987
# Scraping article 51: https://www.bbc.com/sport/football/66837787
# Title does not contain a digit: Premier League predictions: Chris Sutton v British MMA star Fabian Edwards
# Scraping article 52: https://www.bbc.com/sport/football/66828985
# Scraping article 53: https://www.bbc.com/sport/football/66828988
# Scraping article 54: https://www.bbc.com/sport/football/66828986
# Scraping article 55: https://www.bbc.com/sport/football/66835406
# Scraping article 56: https://www.bbc.com/sport/football/66835402
# Scraping article 57: https://www.bbc.com/sport/football/66835404
# Scraping article 58: https://www.bbc.com/sport/football/66835409
# Scraping article 59: https://www.bbc.com/sport/football/66835401
# Scraping article 60: https://www.bbc.com/sport/football/66899186
# Scraping article 61: https://www.bbc.com/sport/football/66899181
# Scraping article 62: https://www.bbc.com/sport/football/66899180
# Scraping article 63: https://www.bbc.com/sport/football/66899190
# Scraping article 64: https://www.bbc.com/sport/football/66899194
# Scraping article 65: https://www.bbc.com/sport/football/66899184
# Scraping article 66: https://www.bbc.com/sport/football/66899179
# Scraping article 67: https://www.bbc.com/sport/football/66899191
# Scraping article 68: https://www.bbc.com/sport/football/66904526
# Scraping article 69: https://www.bbc.com/sport/football/66909069
# Scraping article 70: https://www.bbc.com/sport/football/66482702
# Scraping article 71: https://www.bbc.com/sport/football/66969158
# Scraping article 72: https://www.bbc.com/sport/football/66969161
# Scraping article 73: https://www.bbc.com/sport/football/66969159
# Scraping article 74: https://www.bbc.com/sport/football/66969160
# Scraping article 75: https://www.bbc.com/sport/football/66969157
# Scraping article 76: https://www.bbc.com/sport/football/66969156
# Scraping article 77: https://www.bbc.com/sport/football/66974884
# Scraping article 78: https://www.bbc.com/sport/football/66974881
# Scraping article 79: https://www.bbc.com/sport/football/66974883
# Scraping article 80: https://www.bbc.com/sport/football/66974882
# Scraping article 81: https://www.bbc.com/sport/football/67109092
# Scraping article 82: https://www.bbc.com/sport/football/67109086
# Scraping article 83: https://www.bbc.com/sport/football/67109088
# Scraping article 84: https://www.bbc.com/sport/football/67109091
# Scraping article 85: https://www.bbc.com/sport/football/67109089
# Scraping article 86: https://www.bbc.com/sport/football/67109087
# Scraping article 87: https://www.bbc.com/sport/football/67109093
# Scraping article 88: https://www.bbc.com/sport/football/67109090
# Scraping article 89: https://www.bbc.com/sport/football/67114486
# Scraping article 90: https://www.bbc.com/sport/football/67119440
# Scraping article 91: https://www.bbc.com/sport/football/67165823
# Scraping article 92: https://www.bbc.com/sport/football/67179273
# Scraping article 93: https://www.bbc.com/sport/football/67179274
# Scraping article 94: https://www.bbc.com/sport/football/67179271
# Scraping article 95: https://www.bbc.com/sport/football/67179272
# Scraping article 96: https://www.bbc.com/sport/football/67185671
# Scraping article 97: https://www.bbc.com/sport/football/67185667
# Scraping article 98: https://www.bbc.com/sport/football/67185670
# Scraping article 99: https://www.bbc.com/sport/football/67185668
# Scraping article 100: https://www.bbc.com/sport/football/67185669
# Scraping article 101: https://www.bbc.com/sport/football/67247521
# Scraping article 102: https://www.bbc.com/sport/football/67247516
# Scraping article 103: https://www.bbc.com/sport/football/67247522
# Scraping article 104: https://www.bbc.com/sport/football/67247518
# Scraping article 105: https://www.bbc.com/sport/football/67247520
# Scraping article 106: https://www.bbc.com/sport/football/67247517
# Scraping article 107: https://www.bbc.com/sport/football/67247519
# Scraping article 108: https://www.bbc.com/sport/football/67253241
# Scraping article 109: https://www.bbc.com/sport/football/67253234
# Scraping article 110: https://www.bbc.com/sport/football/67258895
# Scraping article 111: https://www.bbc.com/sport/football/67318575
# Scraping article 112: https://www.bbc.com/sport/football/67318574
# Scraping article 113: https://www.bbc.com/sport/football/67318576
# Scraping article 114: https://www.bbc.com/sport/football/67318578
# Scraping article 115: https://www.bbc.com/sport/football/67318573
# Scraping article 116: https://www.bbc.com/sport/football/67325045
# Scraping article 117: https://www.bbc.com/sport/football/67325042
# Scraping article 118: https://www.bbc.com/sport/football/67325044
# Scraping article 119: https://www.bbc.com/sport/football/67325043
# Scraping article 120: https://www.bbc.com/sport/football/67325041
# Scraping article 121: https://www.bbc.com/sport/football/67521024
# Title does not contain a digit: Manchester City v Liverpool: Everton points-protest banner one of two flown over Etihad
# Scraping article 122: https://www.bbc.com/sport/football/67460116
# Scraping article 123: https://www.bbc.com/sport/football/67460120
# Scraping article 124: https://www.bbc.com/sport/football/67460117
# Scraping article 125: https://www.bbc.com/sport/football/67460121
# Scraping article 126: https://www.bbc.com/sport/football/67460122
# Scraping article 127: https://www.bbc.com/sport/football/67460119
# Scraping article 128: https://www.bbc.com/sport/football/67466092
# Scraping article 129: https://www.bbc.com/sport/football/67528725
# Scraping article 130: https://www.bbc.com/sport/football/67470815
# Scraping article 131: https://www.bbc.com/sport/football/67528620
# Scraping article 132: https://www.bbc.com/sport/football/67528613
# Scraping article 133: https://www.bbc.com/sport/football/67528610
# Scraping article 134: https://www.bbc.com/sport/football/67528612
# Scraping article 135: https://www.bbc.com/sport/football/67528611
# Scraping article 136: https://www.bbc.com/sport/football/67534877
# Scraping article 137: https://www.bbc.com/sport/football/67534874
# Scraping article 138: https://www.bbc.com/sport/football/67534871
# Scraping article 139: https://www.bbc.com/sport/football/67534870
# Scraping article 140: https://www.bbc.com/sport/football/67534869
# Scraping article 141: https://www.bbc.com/sport/football/67551132
# Scraping article 142: https://www.bbc.com/sport/football/67551131
# Scraping article 143: https://www.bbc.com/sport/football/67562710
# Scraping article 144: https://www.bbc.com/sport/football/67562689
# Scraping article 145: https://www.bbc.com/sport/football/67562685
# Scraping article 146: https://www.bbc.com/sport/football/67562684
# Scraping article 147: https://www.bbc.com/sport/football/67562686
# Scraping article 148: https://www.bbc.com/sport/football/67562688
# Scraping article 149: https://www.bbc.com/sport/football/67656063
# Scraping article 150: https://www.bbc.com/sport/football/67574361
# Scraping article 151: https://www.bbc.com/sport/football/67598698
# Scraping article 152: https://www.bbc.com/sport/football/67598702
# Scraping article 153: https://www.bbc.com/sport/football/67598697
# Scraping article 154: https://www.bbc.com/sport/football/67598699
# Scraping article 155: https://www.bbc.com/sport/football/67598696
# Scraping article 156: https://www.bbc.com/sport/football/67598695
# Scraping article 157: https://www.bbc.com/sport/football/67604927
# Scraping article 158: https://www.bbc.com/sport/football/67604926
# Scraping article 159: https://www.bbc.com/sport/football/67604922
# Scraping article 160: https://www.bbc.com/sport/football/67632552
# Title does not contain a digit: Premier League predictions: Chris Sutton v Vigil star Dougray Scott
# Scraping article 161: https://www.bbc.com/sport/football/67656405
# Scraping article 162: https://www.bbc.com/sport/football/67667800
# Scraping article 163: https://www.bbc.com/sport/football/67667796
# Scraping article 164: https://www.bbc.com/sport/football/67667797
# Scraping article 165: https://www.bbc.com/sport/football/67667799
# Scraping article 166: https://www.bbc.com/sport/football/67673776
# Scraping article 167: https://www.bbc.com/sport/football/67673772
# Scraping article 168: https://www.bbc.com/sport/football/67673771
# Scraping article 169: https://www.bbc.com/sport/football/67673773
# Scraping article 170: https://www.bbc.com/sport/football/67712020
# Scraping article 171: https://www.bbc.com/sport/football/67724150
# Scraping article 172: https://www.bbc.com/sport/football/67735460
# Scraping article 173: https://www.bbc.com/sport/football/67735461
# Scraping article 174: https://www.bbc.com/sport/football/67735455
# Scraping article 175: https://www.bbc.com/sport/football/67735454
# Scraping article 176: https://www.bbc.com/sport/football/67735453
# Scraping article 177: https://www.bbc.com/sport/football/67728437
# Title does not contain a digit: Premier League Christmas & New Year fixtures: Full festive schedule and kick-off times
# Scraping article 178: https://www.bbc.com/sport/football/67740568
# Scraping article 179: https://www.bbc.com/sport/football/67757165
# Scraping article 180: https://www.bbc.com/sport/football/67757163
# Scraping article 181: https://www.bbc.com/sport/football/67757162
# Scraping article 182: https://www.bbc.com/sport/football/67757166
# Scraping article 183: https://www.bbc.com/sport/football/67757164
# Scraping article 184: https://www.bbc.com/sport/football/67768992
# Scraping article 185: https://www.bbc.com/sport/football/67768994
# Scraping article 186: https://www.bbc.com/sport/football/67768993
# Scraping article 187: https://www.bbc.com/sport/football/67782972
# Scraping article 188: https://www.bbc.com/sport/football/67782971
# Scraping article 189: https://www.bbc.com/sport/football/67809567
# Scraping article 190: https://www.bbc.com/sport/football/67809568
# Scraping article 191: https://www.bbc.com/sport/football/67809578
# Scraping article 192: https://www.bbc.com/sport/football/67809577
# Scraping article 193: https://www.bbc.com/sport/football/67809569
# Scraping article 194: https://www.bbc.com/sport/football/67809573
# Scraping article 195: https://www.bbc.com/sport/football/67814391
# Scraping article 196: https://www.bbc.com/sport/football/67814390
# Scraping article 197: https://www.bbc.com/sport/football/67860036
# Scraping article 198: https://www.bbc.com/sport/football/67821084
# Scraping article 199: https://www.bbc.com/sport/football/67908070
# Scraping article 200: https://www.bbc.com/sport/football/67900156
# Scraping article 201: https://www.bbc.com/sport/football/67900157
# Scraping article 202: https://www.bbc.com/sport/football/67904869
# Scraping article 203: https://www.bbc.com/sport/football/67904868
# Scraping article 204: https://www.bbc.com/sport/football/67966595
# Scraping article 205: https://www.bbc.com/sport/football/67966593
# Scraping article 206: https://www.bbc.com/sport/football/67972912
# Scraping article 207: https://www.bbc.com/sport/football/67972911
# Scraping article 208: https://www.bbc.com/sport/football/67977924
# Scraping article 209: https://www.bbc.com/sport/football/68065096
# Scraping article 210: https://www.bbc.com/sport/football/68065095
# Scraping article 211: https://www.bbc.com/sport/football/68065089
# Scraping article 212: https://www.bbc.com/sport/football/68065091
# Scraping article 213: https://www.bbc.com/sport/football/68065090
# Scraping article 214: https://www.bbc.com/sport/football/68077795
# Scraping article 215: https://www.bbc.com/sport/football/68077797
# Scraping article 216: https://www.bbc.com/sport/football/68077796
# Scraping article 217: https://www.bbc.com/sport/football/68090232
# Scraping article 218: https://www.bbc.com/sport/football/68090233
# Scraping article 219: https://www.bbc.com/sport/football/68115073
# Scraping article 220: https://www.bbc.com/sport/football/68115068
# Scraping article 221: https://www.bbc.com/sport/football/68115069
# Scraping article 222: https://www.bbc.com/sport/football/68115067
# Scraping article 223: https://www.bbc.com/sport/football/68115071
# Scraping article 224: https://www.bbc.com/sport/football/68120818
# Scraping article 225: https://www.bbc.com/sport/football/68120825
# Scraping article 226: https://www.bbc.com/sport/football/68120824
# Scraping article 227: https://www.bbc.com/sport/football/68120819
# Scraping article 228: https://www.bbc.com/sport/football/68125416
# Scraping article 229: https://www.bbc.com/sport/football/68190261
# Scraping article 230: https://www.bbc.com/sport/football/68190260
# Scraping article 231: https://www.bbc.com/sport/football/68190258
# Scraping article 232: https://www.bbc.com/sport/football/68190262
# Scraping article 233: https://www.bbc.com/sport/football/68190257
# Scraping article 234: https://www.bbc.com/sport/football/68190259
# Scraping article 235: https://www.bbc.com/sport/football/68190256
# Scraping article 236: https://www.bbc.com/sport/football/68196268
# Scraping article 237: https://www.bbc.com/sport/football/68196269
# Scraping article 238: https://www.bbc.com/sport/football/68201307
# Scraping article 239: https://www.bbc.com/sport/football/68260175
# Scraping article 240: https://www.bbc.com/sport/football/68260174
# Scraping article 241: https://www.bbc.com/sport/football/68260180
# Scraping article 242: https://www.bbc.com/sport/football/68260179
# Scraping article 243: https://www.bbc.com/sport/football/68260177
# Scraping article 244: https://www.bbc.com/sport/football/68268878
# Title does not contain a digit: Premier League predictions: Chris Sutton v rapper & Chelsea fan Songer
# Scraping article 245: https://www.bbc.com/sport/football/68260178
# Scraping article 246: https://www.bbc.com/sport/football/68266300
# Scraping article 247: https://www.bbc.com/sport/football/68266299
# Scraping article 248: https://www.bbc.com/sport/football/68271037
# Scraping article 249: https://www.bbc.com/sport/football/67735458
# Scraping article 250: https://www.bbc.com/sport/football/68291379
# Scraping article 251: https://www.bbc.com/sport/football/68324368
# Scraping article 252: https://www.bbc.com/sport/football/68324367
# Scraping article 253: https://www.bbc.com/sport/football/68324370
# Scraping article 254: https://www.bbc.com/sport/football/68324369
# Scraping article 255: https://www.bbc.com/sport/football/68324372
# Scraping article 256: https://www.bbc.com/sport/football/68324371
# Scraping article 257: https://www.bbc.com/sport/football/68329943
# Scraping article 258: https://www.bbc.com/sport/football/68334668
# Scraping article 259: https://www.bbc.com/sport/football/68389646
# Scraping article 260: https://www.bbc.com/sport/football/68389649
# Scraping article 261: https://www.bbc.com/sport/football/68389645
# Scraping article 262: https://www.bbc.com/sport/football/68389647
# Scraping article 263: https://www.bbc.com/sport/football/68389651
# Scraping article 264: https://www.bbc.com/sport/football/68389650
# Scraping article 265: https://www.bbc.com/sport/football/68389648
# Scraping article 266: https://www.bbc.com/sport/football/68389649
# Scraping article 267: https://www.bbc.com/sport/football/68395537
# Scraping article 268: https://www.bbc.com/sport/football/68399653
# Scraping article 269: https://www.bbc.com/sport/football/68455051
# Scraping article 270: https://www.bbc.com/sport/football/68455053
# Scraping article 271: https://www.bbc.com/sport/football/68455050
# Scraping article 272: https://www.bbc.com/sport/football/68455052
# Scraping article 273: https://www.bbc.com/sport/football/68455049
# Scraping article 274: https://www.bbc.com/sport/football/68460857
# Scraping article 275: https://www.bbc.com/sport/football/68460863
# Scraping article 276: https://www.bbc.com/sport/football/68460859
# Scraping article 277: https://www.bbc.com/sport/football/68460858
# Scraping article 278: https://www.bbc.com/sport/football/68464958
# Scraping article 279: https://www.bbc.com/sport/football/67875771
# Scraping article 280: https://www.bbc.com/sport/football/68519748
# Scraping article 281: https://www.bbc.com/sport/football/68519750
# Scraping article 282: https://www.bbc.com/sport/football/68519744
# Scraping article 283: https://www.bbc.com/sport/football/68526441
# Scraping article 284: https://www.bbc.com/sport/football/68644056
# Scraping article 285: https://www.bbc.com/sport/football/68644062
# Scraping article 286: https://www.bbc.com/sport/football/68644055
# Scraping article 287: https://www.bbc.com/sport/football/68644054
# Scraping article 288: https://www.bbc.com/sport/football/68644069
# Scraping article 289: https://www.bbc.com/sport/football/68644057
# Scraping article 290: https://www.bbc.com/sport/football/68644067
# Scraping article 291: https://www.bbc.com/sport/football/68644069
# Scraping article 292: https://www.bbc.com/sport/football/68648917
# Scraping article 293: https://www.bbc.com/sport/football/68648918
# Scraping article 294: https://www.bbc.com/sport/football/68662320
# Scraping article 295: https://www.bbc.com/sport/football/68662326
# Scraping article 296: https://www.bbc.com/sport/football/68662324
# Scraping article 297: https://www.bbc.com/sport/football/68662321
# Scraping article 298: https://www.bbc.com/sport/football/68662323
# Scraping article 299: https://www.bbc.com/sport/football/68672061
# Scraping article 300: https://www.bbc.com/sport/football/68672062
# Scraping article 301: https://www.bbc.com/sport/football/68672065
# Scraping article 302: https://www.bbc.com/sport/football/68681424
# Scraping article 303: https://www.bbc.com/sport/football/68681425
# Scraping article 304: https://www.bbc.com/sport/football/68697135
# Scraping article 305: https://www.bbc.com/sport/football/68697132
# Scraping article 306: https://www.bbc.com/sport/football/68697131
# Scraping article 307: https://www.bbc.com/sport/football/68697127
# Scraping article 308: https://www.bbc.com/sport/football/68697128
# Scraping article 309: https://www.bbc.com/sport/football/68697129
# Scraping article 310: https://www.bbc.com/sport/football/68697130
# Scraping article 311: https://www.bbc.com/sport/football/68756867
# Scraping article 312: https://www.bbc.com/sport/football/68702107
# Scraping article 313: https://www.bbc.com/sport/football/68702109
# Scraping article 314: https://www.bbc.com/sport/football/68747534
# Scraping article 315: https://www.bbc.com/sport/football/68747578
# Scraping article 316: https://www.bbc.com/sport/football/68747537
# Scraping article 317: https://www.bbc.com/sport/football/68747566
# Scraping article 318: https://www.bbc.com/sport/football/68747568
# Scraping article 319: https://www.bbc.com/sport/football/68747554
# Scraping article 320: https://www.bbc.com/sport/football/68814043
# Title does not contain a digit: Premier League title race: 'Arsenal and Liverpool stumble as momentum shifts in Man City's favour'
# Scraping article 321: https://www.bbc.com/sport/football/68754387
# Scraping article 322: https://www.bbc.com/sport/football/68754390
# Scraping article 323: https://www.bbc.com/sport/football/68758438
# Scraping article 324: https://www.bbc.com/sport/football/68804742
# Scraping article 325: https://www.bbc.com/sport/football/68804744
# Scraping article 326: https://www.bbc.com/sport/football/68804746
# Scraping article 327: https://www.bbc.com/sport/football/68810623
# Scraping article 328: https://www.bbc.com/sport/football/68810620
# Scraping article 329: https://www.bbc.com/sport/football/68810622
# Scraping article 330: https://www.bbc.com/sport/football/68810621
# Scraping article 331: https://www.bbc.com/sport/articles/c2jdgzx7g7lo
# Scraping article 332: https://www.bbc.com/sport/football/68519747
# Scraping article 333: https://www.bbc.com/sport/football/68519745
# Scraping article 334: https://www.bbc.com/sport/football/articles/c6pywzp3720o
# Title does not contain a digit: 'Everton apply final blow to Liverpool title challenge'
# Scraping article 335: https://www.bbc.com/sport/football/68519749
# Scraping article 336: https://www.bbc.com/sport/football/68526442
# Scraping article 337: https://www.bbc.com/sport/football/68862599
# Scraping article 338: https://www.bbc.com/sport/football/68862602
# Scraping article 339: https://www.bbc.com/sport/football/68862604
# Scraping article 340: https://www.bbc.com/sport/football/68862603
# Scraping article 341: https://www.bbc.com/sport/football/68862600
# Scraping article 342: https://www.bbc.com/sport/football/68862598
# Scraping article 343: https://www.bbc.com/sport/football/68862601
# Scraping article 344: https://www.bbc.com/sport/football/68867475
# Scraping article 345: https://www.bbc.com/sport/football/68867476
# Scraping article 346: https://www.bbc.com/sport/football/68867478
# Scraping article 347: https://www.bbc.com/sport/football/68313376
# Scraping article 348: https://www.bbc.com/sport/football/68902721
# Scraping article 349: https://www.bbc.com/sport/football/68910649
# Scraping article 350: https://www.bbc.com/sport/football/68910652
# Scraping article 351: https://www.bbc.com/sport/football/68910651
# Scraping article 352: https://www.bbc.com/sport/football/68910650
# Scraping article 353: https://www.bbc.com/sport/football/68910648
# Scraping article 354: https://www.bbc.com/sport/football/68914705
# Scraping article 355: https://www.bbc.com/sport/football/articles/cnke30wy8k7o
# Scraping article 356: https://www.bbc.com/sport/football/68914707
# Scraping article 357: https://www.bbc.com/sport/football/68918237
# Scraping article 358: https://www.bbc.com/sport/football/live/cz4x5p9r0lgt
# Scraping article 359: https://www.bbc.com/sport/football/articles/cjk464gm1z6o
# Scraping article 360: https://www.bbc.com/sport/football/live/c4g04dnge5xt
# Scraping article 361: https://www.bbc.com/sport/football/live/cekl5d2rz3lt
# Scraping article 362: https://www.bbc.com/sport/football/articles/c2jd5gm2l44o
# Scraping article 363: https://www.bbc.com/sport/football/live/cz96er3j844t
# Scraping article 364: https://www.bbc.com/sport/football/live/c51nzlpjvzwt
# Scraping article 365: https://www.bbc.com/sport/football/live/cjjeg9v7y67t
# Scraping article 366: https://www.bbc.com/sport/football/live/cn0rndpvx20t
# Scraping article 367: https://www.bbc.com/sport/football/live/cpwg7qpeeeet
# Scraping article 368: https://www.bbc.com/sport/football/live/crrd9w8z72gt
# Scraping article 369: https://www.bbc.com/sport/football/live/c6pyj53r8glt
# Scraping article 370: https://www.bbc.co.uk/sport/football/live/c99z4p7ek5qt
# Scraping article 371: https://www.bbc.com/sport/football/live/cq5n52d81zpt
# Scraping article 372: https://www.bbc.com/sport/football/live/c0v0vrg7y89t
# Scraping article 373: https://www.bbc.com/sport/football/live/cxr3rxevw4qt
# Scraping article 374: https://www.bbc.com/sport/football/live/c0lz8w9gkrxt
# Scraping article 375: https://www.bbc.com/sport/football/live/cm2ldj59375t
# Scraping article 376: https://www.bbc.com/sport/football/live/c4n1nrd4yzpt
# Scraping article 377: https://www.bbc.com/sport/football/live/c2kgd9q4jnxt
# Scraping article 378: https://www.bbc.com/sport/football/live/cz747jdx93nt
# Scraping article 379: https://www.bbc.com/sport/football/live/crgygk217e4t
# Scraping article 380: https://www.bbc.com/sport/football/live/c72p20zqyzjt
# Output saved to epl_sentiment_analysis/bbc_articles/bbc_articles_2023.json

# %% [markdown]
# Finding articles for corrected entries in output file with articles

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import json
import os

def scrape_bbc_article(url_to_scrape):

    driver = webdriver.Chrome()
    #set timeout to 10 seconds
    driver.implicitly_wait(10)
    driver.get(url_to_scrape)

    #find by id='main-content
    main_tag = driver.find_element(By.ID, 'main-content')

    #Find all h1 tags
    #find all div tag with data-component="subheadline-block" or data-component="text-block"
    blocks =main_tag.find_elements(By.TAG_NAME, 'h1')
    blocks = blocks + main_tag.find_elements(By.CSS_SELECTOR, 'div[data-component="subheadline-block"], div[data-component="text-block"]')

    #check that the title contains a digit at least
    #if not, return None
    """ title = blocks[0].text if blocks else None
    if title and not any(char.isdigit() for char in title): #might need to override this at times
        print(f"Title does not contain a digit: {title}")
        driver.quit()
        return None """
    #get the text from the blocks and concatenate them in a string, with new line between each block
    text_blocks = [block.text for block in blocks]
    commentary_text = "\n".join(text_blocks)

    #Close the browser
    driver.quit()

    return commentary_text

output_file = "../dataset/epl_sentiment_analysis/bbc_articles/bbc_articles_2023.json"

with open(output_file, "r") as file:
    existing_data = json.load(file)
    print(f"Loaded existing data from {output_file}")


output = []
for item in existing_data:
    if item.get('article_text') is None:
        try:
            bbc_link = item.get('bbc_link')
            if bbc_link:
                print(f"Scraping article: {bbc_link}")
                article_text = scrape_bbc_article(bbc_link)
                item['article_text'] = article_text
            else:
                item['article_text'] = None

            output.append(item)
        except Exception as e:
            print(f"Error scraping {item['bbc_link']}: {e}")
            item['article_text'] = None

    else:
        output.append(item)

#save the output to the same file
with open(output_file, "w") as file:
    json.dump(output, file, indent=4)
print(f"Output saved to {output_file}")
# Out:
# Loaded existing data from epl_sentiment_analysis/bbc_articles/bbc_articles_2023.json
# Scraping article: https://www.bbc.com/sport/football/66828984
# Scraping article: https://www.bbc.com/sport/football/67460118
# Scraping article: https://www.bbc.com/sport/football/67604923
# Scraping article: https://www.bbc.com/sport/football/67814111
# Scraping article: https://www.bbc.com/sport/football/68260176
# Scraping article: https://www.bbc.com/sport/articles/cz4xvrz8ep4o
# Scraping article: https://www.bbc.com/sport/football/articles/c6pywzp3720o
# Output saved to epl_sentiment_analysis/bbc_articles/bbc_articles_2023.json

# %% [markdown]
# For Each Match, Find The Relevant Articles Of The Home And Way Team From The Previous Match

# %%
""" 
Each entry looks like this:
    {
    "id": 192297,
    "date": "2015-08-08",
    "home_team": "Manchester United",
    "away_team": "Tottenham",
    "bbc_link": "https://www.bbc.com/sport/football/33744640",
    "article_text": "Manchester United 1-0 Tottenham Hotspur\nManchester United held on to start their season with a lacklustre win against Tottenham thanks to Kyle Walker's early own goal.\nAfter Christian Eriksen lobbed over when clean through, United went ahead as Walker poked into his own net when attempting to tackle Wayne Rooney.\nThat led to a better spell for United, who did not have a shot on target until Ashley Young's 65th-minute effort.\nSergio Romero - one of five United debutants - saved a late Eriksen drive.\nRelive Manchester United's win over Tottenham\n, external\nLouis van Gaal celebrated his 64th birthday with a victory but his team were hanging on towards the end as Romero was twice called into action.\nTottenham - who finished fifth in the Premier League last season, six points behind United - started and ended the game strongly only three days after completing their final pre-season game against AC Milan in Germany.\nHow did United's debutants perform?\nMorgan Schneiderlin was the pick of United's new recruits, who cost a combined \u00a383.1m over the summer.\nThe defensive midfielder lined up next to Michael Carrick and looked energetic and willing to accept possession deep in United's half despite a couple of nervous moments early on.\nThe \u00a325m capture from Southampton was put under pressure by goalkeeper Romero, whose kicking lacked conviction after Spurs pressed the hosts' defence high up the pitch.\nThe Argentine international made his debut after replacing David De Gea, who boss Van Gaal said was \"not capable\" of playing amid ongoing speculation that the Spanish goalkeeper wants to join Real Madrid.\nMemphis Depay, a \u00a331m arrival from PSV Eindhoven, played behind Wayne Rooney in attack, and while the Dutch 21-year-old did have an early shot blocked, he was frustrated by his 68th-minute substitution after a display where he looked like he needed further time to gel with team-mates.\nAt right-back Matteo Darmian was solid as a replacement for the departed Rafael Da Silva and showed purpose going forward.\nBastian Schweinsteiger, who came on for Carrick after his \u00a314.4m arrival from Bayern Munich, helped see the game out with some clever touches but was booked shortly after being introduced after an hour.\nKane shows signs of promise\nDespite a gruelling summer in which he went on Spurs' post-season tour to Australia and played in the England Under-21s' ill-fated European Championship campaign, Kane looked sharp in the first half.\nHe made a great start to the game, setting up Eriksen for his side's best chance after five minutes, but a lack of support meant Spurs's top scorer from last season faded and Chris Smalling began to boss the United defence in an impressive display.\nBut the 22-year-old did show promise after questions whether he could follow up last season's superb form.\nTottenham boss Mauricio Pochettino withdrew Nabil Bentaleb eight minutes into the second half after the 20-year-old lined up with Eric Dier in the centre of midfield and gave the ball away for the goal.\nHowever, he will have been pleased by the overall performance of his team, with \u00a312m debutant Toby Alderweireld looking strong next to fellow Belgian Jan Vertonghen in the centre of their defence.\n'Depay too eager'\nManchester United manager Louis Van Gaal: \"I said to Memphis that he doesn't have to play too eagerly and with too much passion and that counts for the whole team. But it's always the same - the first time you play at Old Trafford it's always difficult, but I liked the performance especially from Darmian.\"\nTottenahm defender Kyle Walker on his own goal: \"I tried to stick my foot in the way so that [Rooney would] kick my foot instead of the ball, so it's a bit unlucky really as I'd made up a lot of ground to get there.\"\nVan Gaal on David De Gea's future at Manchester United: \"I'm not the most important part. The most important part is the player and the club who wants to buy him. He's our best player for the past two or three years so we cannot let him go so easily. We want to sell at the same level as we pay. We want to keep him of course.\"\nPundit reaction\nFormer England winger Chris Waddle on BBC Radio 5 live: \"I don't think either team we've watched looked like title contenders. We haven't seen the best of them. They look a little leggy. Tottenham need a bit of pace and with United I'm not sure about them in the centre-back position.\"\nMan of the match\nChris Smalling offered a calmness and reassurance in defence while many debutants tried too hard to impress. He benefitted from the presence of Morgan Schneiderlin in front of him.\nThe stats you need to know\nThis is the first time a Premier League season's first goal has been an own goal\nManchester United have kept a clean sheet on opening day for the first time since 2010 (3-0 v Newcastle)\nUnited have lost just one of their last 24 opening league games of the season at Old Trafford (W17 D6)\nMauricio Pochettino's Spurs are yet to score against Manchester United in three meetings\nManchester United have now won back-to-back Premier League games against Spurs, after a five game winless run (D3 L2)"
}

Transform to this format:
{
    "id": 192297,
    "date": "2015-08-08",
    "home_team": "Manchester United",
    "away_team": "Tottenham",
    "home team_last_match_date": "2015-08-08",
    "away_team_last_match_date": "2015-08-08",
    "bbc_link_home_team_last_match": "https://www.bbc.com/sport/football/33744640",
    "bbc_link_away_team_last_match": "https://www.bbc.com/sport/football/33744640",
    "bbc_article_home_team_last_match" : ".......",
    "bbc_article_away_team_last_match" : ".......",
}
    """


import json
from bisect import bisect_left

input_file = "../dataset/epl_sentiment_analysis/bbc_articles/bbc_articles_2023.json"
output_file = "../dataset/epl_sentiment_analysis/bbc_articles_collated/bbc_collated_articles_2023.json"

# Load the input JSON file
with open(input_file, 'r') as f:
    input_list = json.load(f)

# Preprocess: create a dictionary mapping each team to a sorted list of their matches by date
team_to_matches = {}
for match in input_list:
    home_team = match['home_team']
    away_team = match['away_team']
    for team in [home_team, away_team]:
        if team not in team_to_matches:
            team_to_matches[team] = []
        team_to_matches[team].append(match)

# Sort each team's matches by date
for team in team_to_matches:
    team_to_matches[team].sort(key=lambda x: x['date'])

output_list = []

for current_match in input_list:
    transformed = {
        "id": current_match["id"],
        "date": current_match["date"],
        "home_team": current_match["home_team"],
        "away_team": current_match["away_team"],
        "home_team_last_match_date": None,
        "away_team_last_match_date": None,
        "bbc_link_home_team_last_match": None,
        "bbc_link_away_team_last_match": None,
        "bbc_article_home_team_last_match": None,
        "bbc_article_away_team_last_match": None
    }
    
    current_date = current_match["date"]
    home_team = current_match["home_team"]
    away_team = current_match["away_team"]
    
    # Process home team's last match
    if home_team in team_to_matches:
        home_matches = team_to_matches[home_team]
        dates = [m['date'] for m in home_matches]
        index = bisect_left(dates, current_date) - 1
        if index >= 0:
            # Iterate backwards to find the latest match that is not the current one
            for i in range(index, -1, -1):
                candidate = home_matches[i]
                if candidate['id'] != current_match['id'] and candidate['date'] < current_date:
                    transformed["home_team_last_match_date"] = candidate["date"]
                    transformed["bbc_link_home_team_last_match"] = candidate["bbc_link"]
                    transformed["bbc_article_home_team_last_match"] = candidate["article_text"]
                    break
    
    # Process away team's last match
    if away_team in team_to_matches:
        away_matches = team_to_matches[away_team]
        dates = [m['date'] for m in away_matches]
        index = bisect_left(dates, current_date) - 1
        if index >= 0:
            for i in range(index, -1, -1):
                candidate = away_matches[i]
                if candidate['id'] != current_match['id'] and candidate['date'] < current_date:
                    transformed["away_team_last_match_date"] = candidate["date"]
                    transformed["bbc_link_away_team_last_match"] = candidate["bbc_link"]
                    transformed["bbc_article_away_team_last_match"] = candidate["article_text"]
                    break
    
    output_list.append(transformed)

# Write the transformed list to the output file
with open(output_file, 'w') as f:
    json.dump(output_list, f, indent=4)
